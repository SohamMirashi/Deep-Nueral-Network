# %%
import numpy as np

# %%
# parameters
m = 2.5      # slope
c = 1.5      # intercept
noise_level = 2.3462

# %%
# create 100 x-values (e.g. spanning 0 to 10)
x = np.linspace(0, 50, 100)

# %%
# create noise term
noise = np.random.normal(loc=0, scale=noise_level, size=100)

# %%
# compute y values
# y = m * x + c + noise
# y = (m*x + c + noise).astype(int)
y = (m*x + c + noise)

# %%
print(x, "\n\n")
print(y)
# Out:
# [ 0.          0.50505051  1.01010101  1.51515152  2.02020202  2.52525253
#   3.03030303  3.53535354  4.04040404  4.54545455  5.05050505  5.55555556
#   6.06060606  6.56565657  7.07070707  7.57575758  8.08080808  8.58585859
#   9.09090909  9.5959596  10.1010101  10.60606061 11.11111111 11.61616162
#  12.12121212 12.62626263 13.13131313 13.63636364 14.14141414 14.64646465
#  15.15151515 15.65656566 16.16161616 16.66666667 17.17171717 17.67676768
#  18.18181818 18.68686869 19.19191919 19.6969697  20.2020202  20.70707071
#  21.21212121 21.71717172 22.22222222 22.72727273 23.23232323 23.73737374
#  24.24242424 24.74747475 25.25252525 25.75757576 26.26262626 26.76767677
#  27.27272727 27.77777778 28.28282828 28.78787879 29.29292929 29.7979798
#  30.3030303  30.80808081 31.31313131 31.81818182 32.32323232 32.82828283
#  33.33333333 33.83838384 34.34343434 34.84848485 35.35353535 35.85858586
#  36.36363636 36.86868687 37.37373737 37.87878788 38.38383838 38.88888889
#  39.39393939 39.8989899  40.4040404  40.90909091 41.41414141 41.91919192
#  42.42424242 42.92929293 43.43434343 43.93939394 44.44444444 44.94949495
#  45.45454545 45.95959596 46.46464646 46.96969697 47.47474747 47.97979798
#  48.48484848 48.98989899 49.49494949 50.        ]
#
#
# [  2.89024978   6.24396976   5.45253668   7.58836609   1.21253914
#    8.20799772   6.32233768   9.25802136  14.35699485  12.4296251
#   15.72372539  14.69177765  16.54340203  15.24788313  18.30972137
#   18.00428157  23.59371678  22.27064723  23.91163191  25.38260408
#   26.8420154   30.67557178  30.07564207  28.89281739  32.34152734
#   31.91428504  32.35880129  36.2361552   36.67518374  37.35938437
#   37.47981419  39.42461385  38.11923085  42.28423256  47.33777722
#   49.04121373  48.26883236  45.50613146  49.72994724  53.03897344
#   53.58480639  53.66055279  55.34235972  55.87057715  55.3243924
#   55.1011142   62.63335741  58.1277981   60.09906533  62.18119084
#   64.10643908  67.67507704  68.22196762  69.04860122  72.65989548
#   72.03528253  71.0501747   74.45755622  74.60973121  77.82745606
#   75.08039198  77.57350373  76.48786861  78.74141618  82.59160428
#   86.33401541  85.82431312  82.6007489   85.768695    86.42100396
#   89.9232854   91.12480872  96.13232957  94.60984547  94.88722593
#   93.99128894 100.31357383  99.70576251 100.75870636 105.85135642
#  104.96312167 100.0887668  112.27348552 110.42526983 107.17179566
#  103.47632247 112.10128741 114.26411735 115.39931023 114.56091765
#  113.44989391 110.76664    112.597264   116.96803209 123.14611005
#  124.30388938 120.79390244 124.20416122 123.01393984 128.14811951]

# %%
import matplotlib.pyplot as plt

# plt.scatter(x, y)
# plt.xlabel("x values")
# plt.ylabel("y values")
# plt.title("Scatter Plot of y = mx + c + noise")
# plt.show()

alpha = 0.0001
w = 0.0
b = 0.0
epochs = 3000

for _ in range(epochs):
    for xi, yi in zip(x, y):
        y_pred = w * xi + b
        error = yi - y_pred
        w += alpha * error * xi
        b += alpha * error

print("Learned w:", w)
print("Learned b:", b)

# Plot results
plt.scatter(x, y, label="Data")
y_pred_line = [w*xi + b for xi in x]
plt.plot(x, y_pred_line, color='red', label="Regression Line")
plt.legend()
plt.show()
# Out:
# Learned w: 2.4975819132043937
# Learned b: 1.5046348282962079

# %%
from faker import Faker

fake = Faker()

# Parameters
m = 2
c = 1
noise_level = 3

# Generate 100 fake integer x-values
x = [fake.random_int(min=0, max=150) for _ in range(100)]

# Generate matching noise values
noise = [fake.random_int(min=-noise_level, max=noise_level) for _ in range(100)]

# Compute y-values using the equation y = mx + c + noise
y = [m * xi + c + ni for xi, ni in zip(x, noise)]

print("x values =", x)
print("y values =", y)
# Out:
# x values = [141, 68, 57, 118, 18, 131, 40, 14, 10, 45, 121, 119, 11, 57, 27, 26, 136, 27, 72, 79, 35, 15, 86, 129, 15, 90, 99, 64, 106, 67, 24, 74, 144, 111, 43, 4, 51, 33, 15, 136, 97, 6, 93, 116, 136, 48, 46, 42, 19, 9, 125, 64, 73, 43, 76, 116, 71, 111, 39, 100, 63, 1, 56, 71, 77, 125, 143, 59, 92, 126, 137, 114, 94, 25, 95, 92, 39, 98, 134, 16, 126, 136, 78, 135, 34, 36, 4, 145, 39, 8, 134, 122, 4, 92, 44, 77, 31, 87, 20, 145]
# y values = [281, 139, 118, 236, 34, 260, 81, 30, 18, 88, 245, 236, 22, 115, 54, 56, 276, 57, 148, 161, 70, 29, 175, 259, 29, 178, 199, 127, 211, 138, 47, 147, 288, 222, 88, 8, 106, 64, 28, 271, 192, 16, 189, 231, 271, 98, 94, 85, 36, 18, 252, 131, 148, 88, 152, 230, 146, 223, 79, 200, 129, 4, 113, 143, 157, 254, 288, 116, 186, 251, 274, 228, 192, 49, 190, 188, 77, 199, 269, 36, 250, 271, 154, 269, 70, 74, 10, 288, 77, 20, 268, 248, 11, 187, 90, 152, 61, 176, 41, 291]

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Scatter Plot of y = mx + c + noise")
plt.show()

# %%
from faker import Faker
import matplotlib.pyplot as plt

fake = Faker()

# Parameters
m = 2
c = 1
noise_level = 3

# Data generation
x = [fake.random_int(min=0, max=150) for _ in range(100)]
noise = [fake.random_int(min=-noise_level, max=noise_level) for _ in range(100)]
y = [m * xi + c + ni for xi, ni in zip(x, noise)]

# Sort data for better visualization
# data = list(zip(x, y))
# data.sort()
# x, y = zip(*data)

# Gradient descent
alpha = 0.0001
w = 0.0
b = 0.0
epochs = 50

for _ in range(epochs):
    for xi, yi in zip(x, y):
        y_pred = w * xi + b
        error = yi - y_pred
        w += alpha * error * xi
        b += alpha * error

print("Learned w:", w)
print("Learned b:", b)

# Plot results
plt.scatter(x, y, label="Data")
y_pred_line = [w*xi + b for xi in x]
plt.plot(x, y_pred_line, color='red', label="Regression Line")
plt.legend()
plt.show()
# Out:
# Learned w: 2.038149956076416
# Learned b: 0.13314358654192865
